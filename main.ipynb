# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import re
from nltk.tokenize import word_tokenize
import unicodedata
import nltk

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Sawitt\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Sawitt\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ### Download dataset

# %%
df = pd.read_csv("dataset.csv")

df.head()
# Out:
#           acts                                             prompt  \
# 0  Tech Writer  I want you to act as a tech writer. You will a...
# 1  Tech Writer  I want you to act as a tech writer. You will a...
# 2  Tech Writer  I want you to act as a tech writer. You will a...
# 3  Tech Writer  I want you to act as a tech writer. You will a...
# 4  Tech Writer  I want you to act as a tech writer. You will a...
#
#                                             response  Word count  Grammar  \
# 0  Quick guide — Download, install and open the a...         575     82.0
# 1  Quick guide — Download, install, and open the ...         448     81.0
# 2  How to download, install, and open the app — a...         426     83.0
# 3  Quick guide — Download, install, and open the ...         505     82.0
# 4  How to download, install, and open the app — a...         561     82.0
#
#    Fluency  Clarity  Engagement  Overall Score AI Similarity  Sources Found  \
# 0     61.0     72.0        72.0           72.0           48%            2.0
# 1     53.0     69.0        73.0           68.0           48%            0.0
# 2     40.0     71.0        72.0           65.0           86%            0.0
# 3     48.0     70.0        73.0           67.0           30%            0.0
# 4     47.0     69.0        73.0           67.0           30%            0.0
#
#   Overall Plagiarism Score
# 0                       5%
# 1                       0%
# 2                       0%
# 3                       0%
# 4                       0%

# %% [markdown]
# ### Check dataframe information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   acts                      250 non-null    object
#  1   prompt                    250 non-null    object
#  2   response                  250 non-null    object
#  3   Word count                250 non-null    int64
#  4   Grammar                   248 non-null    float64
#  5   Fluency                   248 non-null    float64
#  6   Clarity                   248 non-null    float64
#  7   Engagement                248 non-null    float64
#  8   Overall Score             248 non-null    float64
#  9   AI Similarity             247 non-null    object
#  10  Sources Found             248 non-null    float64
#  11  Overall Plagiarism Score  248 non-null    object
# dtypes: float64(6), int64(1), object(5)
# memory usage: 23.6+ KB

# %%
non_stopword_df = df.copy()

non_stopword_df.head()
# Out:
#           acts                                             prompt  \
# 0  Tech Writer  I want you to act as a tech writer. You will a...
# 1  Tech Writer  I want you to act as a tech writer. You will a...
# 2  Tech Writer  I want you to act as a tech writer. You will a...
# 3  Tech Writer  I want you to act as a tech writer. You will a...
# 4  Tech Writer  I want you to act as a tech writer. You will a...
#
#                                             response  Word count  Grammar  \
# 0  Quick guide — Download, install and open the a...         575     82.0
# 1  Quick guide — Download, install, and open the ...         448     81.0
# 2  How to download, install, and open the app — a...         426     83.0
# 3  Quick guide — Download, install, and open the ...         505     82.0
# 4  How to download, install, and open the app — a...         561     82.0
#
#    Fluency  Clarity  Engagement  Overall Score AI Similarity  Sources Found  \
# 0     61.0     72.0        72.0           72.0           48%            2.0
# 1     53.0     69.0        73.0           68.0           48%            0.0
# 2     40.0     71.0        72.0           65.0           86%            0.0
# 3     48.0     70.0        73.0           67.0           30%            0.0
# 4     47.0     69.0        73.0           67.0           30%            0.0
#
#   Overall Plagiarism Score
# 0                       5%
# 1                       0%
# 2                       0%
# 3                       0%
# 4                       0%

# %% [markdown]
# ### Data Cleaning

# %%
def clean_text(text):
    # Convert to lowercase
    if isinstance(text, str):
        text = text.lower()
        return text
    return text

def clean_punctuation(text):
    # Remove punctuation characters
    if isinstance(text, str):
        text = re.sub(r'’', '', text)
        text = re.sub(r'[^\s\w]', ' ', text)
        text = re.sub(r'\n', ' ', text)
        text = re.sub(r'[^\D]', ' ', text)
        text = re.sub(r'_+', '', text)
        text = re.sub(r'\b[a-zA-Z]\b', '', text)
        return text
    return text

def normalize_characters(text):
    if isinstance(text, str):
        normalized_text = unicodedata.normalize('NFKD', text).encode('ASCII', 'ignore').decode('utf-8')
        return normalized_text
    return text

def remove_stopword(text):
    stopwords = set(nltk.corpus.stopwords.words('english'))
    filtered_words = [word for word in text.split() if word not in stopwords]
    return ' '.join(filtered_words)

# %%
df['response'] = df['response'].apply(clean_text).apply(clean_punctuation).apply(normalize_characters)

non_stopword_df['response'] = non_stopword_df['response'].apply(clean_text).apply(clean_punctuation).apply(normalize_characters).apply(remove_stopword)

# %%
df['response'].head()
# Out:
# 0    quick guide   download  install and open the a...
# 1    quick guide   download  install  and open the ...
# 2    how to download  install  and open the app    ...
# 3    quick guide   download  install  and open the ...
# 4    how to download  install  and open the app    ...
# Name: response, dtype: object

# %%
non_stopword_df['response'].head()
# Out:
# 0    quick guide download install open app cross pl...
# 1    quick guide download install open app cross pl...
# 2    download install open app quick cross platform...
# 3    quick guide download install open app cross pl...
# 4    download install open app clean cross platform...
# Name: response, dtype: object

# %% [markdown]
# ### Data Preprocessing

# %%
df['response'] = df['response'].apply(word_tokenize)

# %%
non_stopword_df['response'] = non_stopword_df['response'].apply(
    lambda x: word_tokenize(x) if isinstance(x, str) else x
)

# %% [markdown]
# ### Word Frequencies

# %% [markdown]
# #### With stopwords

# %%
freq_df = df[['acts', 'response']]
topics = freq_df['acts'].unique()

for topic in topics:
    all_words = []
    responses = freq_df[freq_df['acts'] == topic]['response']
    for tokens in responses:
        all_words.extend(tokens)

    word_counts = {}
    for word in all_words:
        if word in word_counts:
            word_counts[word] += 1
        else:
            word_counts[word] = 1
        
    print(f"\n================================= Topic: {topic} =================================")
    for word in sorted(word_counts, key=word_counts.get, reverse=True)[:10]:
        if word_counts[word] >= 5:
            print(f"{word}: {word_counts[word]}")
        else:
            continue
    if word_counts:
        avg_repetition = sum(word_counts.values()) / len(word_counts)
        print(f"\nAverage of duplicated words (≥5 reps): {avg_repetition:.2f}")
    else:
        print("\nNo words repeated ≥ 5 times.")
# Out:
# ================================= Topic: Tech Writer =================================
# the: 142
# or: 86
# app: 74
# download: 58
# screenshot: 57
# and: 55
# install: 49
# run: 45
# if: 44
# to: 43
#
# Average of duplicated words (≥5 reps): 6.59
#
# ================================= Topic: Film Critic =================================
# and: 74
# the: 30
# action: 19
# that: 17
# film: 13
# with: 12
# matrix: 10
# reality: 10
# effects: 10
# concept: 9
#
# Average of duplicated words (≥5 reps): 3.25
#
# ================================= Topic: Nutritionist =================================
# and: 49
# tbsp: 29
# to: 28
# salt: 21
# quinoa: 18
# with: 18
# olive: 17
# oil: 17
# tahini: 17
# pepper: 16
#
# Average of duplicated words (≥5 reps): 5.26
#
# ================================= Topic: Babysitter =================================
# to: 22
# and: 21
# for: 17
# or: 16
# bedtime: 15
# with: 14
# snack: 13
# simple: 13
# calm: 13
# quiet: 13
#
# Average of duplicated words (≥5 reps): 3.76
#
# ================================= Topic: Makeup Artist =================================
# and: 48
# for: 44
# cream: 35
# with: 28
# to: 26
# apply: 23
# on: 23
# soft: 20
# hydrating: 18
# skin: 15
#
# Average of duplicated words (≥5 reps): 4.47
#
# ================================= Topic: Public Speaking Coach =================================
# and: 31
# for: 28
# with: 27
# to: 27
# of: 22
# opening: 21
# use: 20
# script: 17
# run: 17
# stage: 15
#
# Average of duplicated words (≥5 reps): 3.93
#
# ================================= Topic: Digital Art Gallery Guide =================================
# and: 64
# for: 54
# room: 27
# or: 26
# curator: 21
# works: 19
# text: 19
# with: 18
# audio: 18
# mvp: 18
#
# Average of duplicated words (≥5 reps): 3.88
#
# ================================= Topic: Journalist =================================
# and: 91
# the: 27
# cities: 25
# of: 24
# to: 24
# in: 24
# air: 23
# for: 20
# pollution: 16
# health: 15
#
# Average of duplicated words (≥5 reps): 2.14
#
# ================================= Topic: Spoken English Teacher and Improver =================================
# you: 29
# to: 12
# first: 11
# question: 11
# me: 8
# more: 8
# do: 8
# and: 8
# ill: 6
# correct: 6
#
# Average of duplicated words (≥5 reps): 2.70
#
# ================================= Topic: Travel Guide =================================
# museum: 52
# galata: 39
# modern: 31
# of: 28
# istanbul: 24
# min: 24
# museums: 22
# and: 22
# day: 22
# cukurcuma: 21
#
# Average of duplicated words (≥5 reps): 4.72
#
# ================================= Topic: Advertiser =================================
# for: 42
# focus: 36
# sampling: 30
# campus: 28
# creative: 26
# social: 23
# influencer: 23
# study: 21
# voltive: 20
# product: 19
#
# Average of duplicated words (≥5 reps): 3.38
#
# ================================= Topic: Salesperson =================================
# you: 18
# and: 15
# to: 13
# your: 11
# free: 10
# so: 10
# day: 8
# trial: 8
# the: 8
# it: 8
#
# Average of duplicated words (≥5 reps): 2.39
#
# ================================= Topic: Wisdom Generator =================================
# and: 69
# one: 61
# to: 27
# with: 21
# the: 20
# weekly: 20
# micro: 18
# day: 18
# for: 15
# week: 13
#
# Average of duplicated words (≥5 reps): 3.69
#
# ================================= Topic: Storyteller =================================
# the: 129
# and: 54
# of: 29
# that: 27
# to: 25
# it: 22
# she: 19
# in: 17
# her: 16
# not: 14
#
# Average of duplicated words (≥5 reps): 2.29
#
# ================================= Topic: Football Commentator =================================
# the: 87
# and: 63
# to: 52
# united: 32
# chelsea: 31
# if: 25
# on: 19
# are: 17
# midfield: 16
# or: 15
#
# Average of duplicated words (≥5 reps): 3.49
#
# ================================= Topic: Stand-up Comedian =================================
# the: 50
# and: 23
# to: 21
# for: 14
# is: 12
# like: 12
# of: 10
# are: 9
# politics: 8
# in: 8
#
# Average of duplicated words (≥5 reps): 2.08
#
# ================================= Topic: Motivational Coach =================================
# or: 33
# min: 26
# to: 25
# and: 25
# exam: 23
# practice: 22
# day: 20
# for: 17
# session: 17
# study: 16
#
# Average of duplicated words (≥5 reps): 3.95
#
# ================================= Topic: Restaurant Owner =================================
# with: 84
# and: 42
# method: 41
# ingredients: 35
# until: 31
# lime: 30
# cilantro: 30
# tortillas: 30
# tacos: 29
# serve: 25
#
# Average of duplicated words (≥5 reps): 5.53
#
# ================================= Topic: Debater =================================
# and: 90
# for: 58
# node: 45
# deno: 40
# in: 27
# is: 26
# with: 26
# or: 26
# native: 25
# ecosystem: 23
#
# Average of duplicated words (≥5 reps): 3.81
#
# ================================= Topic: Debate Coach =================================
# to: 57
# day: 42
# and: 41
# min: 40
# easy: 34
# rebuttal: 28
# evidence: 24
# your: 23
# end: 21
# arguments: 20
#
# Average of duplicated words (≥5 reps): 4.07
#
# ================================= Topic: Screenwriter =================================
# the: 216
# and: 104
# to: 65
# in: 59
# of: 59
# with: 37
# julien: 37
# marc: 30
# at: 27
# on: 27
#
# Average of duplicated words (≥5 reps): 2.55
#
# ================================= Topic: Novelist =================================
# the: 215
# to: 78
# and: 61
# in: 51
# of: 37
# with: 31
# that: 28
# is: 26
# it: 25
# by: 23
#
# Average of duplicated words (≥5 reps): 2.27
#
#  =================================Topic: Movie Critic
# the: 81
# and: 77
# that: 23
# is: 22
# of: 20
# it: 19
# but: 14
# with: 12
# its: 11
# film: 11
#
# Average of duplicated words (≥5 reps): 2.23
#
#  =================================Topic: Relationship Coach
# the: 31
# and: 27
# one: 24
# you: 22
# what: 20
# can: 17
# that: 16
# to: 15
# in: 15
# for: 14
#
# Average of duplicated words (≥5 reps): 2.52
#
# ================================= Topic: Poet =================================
# the: 46
# it: 29
# is: 20
# and: 15
# of: 11
# that: 10
# to: 9
# in: 8
# like: 6
# not: 6
#
# Average of duplicated words (≥5 reps): 2.01
#
#  =================================Topic: Rapper
# the: 127
# in: 57
# my: 44
# to: 33
# hook: 29
# on: 26
# and: 24
# it: 19
# of: 18
# with: 17
#
# Average of duplicated words (≥5 reps): 2.94
#
#  =================================Topic: Motivational Speaker
# the: 56
# you: 42
# not: 35
# is: 33
# to: 20
# it: 19
# when: 19
# and: 18
# one: 18
# are: 15
#
# Average of duplicated words (≥5 reps): 2.44
#
#  =================================Topic: Philosophy Teacher
# and: 51
# what: 47
# the: 38
# to: 37
# example: 32
# you: 28
# ask: 23
# would: 22
# if: 19
# care: 17
#
# Average of duplicated words (≥5 reps): 2.87
#
# ================================= Topic: Philosopher =================================
# and: 114
# the: 30
# decision: 26
# rights: 26
# to: 22
# if: 21
# you: 19
# options: 19
# for: 18
# fairness: 16
#
# Average of duplicated words (≥5 reps): 2.74
#
#  =================================Topic: Math Teacher
# and: 37
# probability: 32
# outcomes: 23
# of: 21
# if: 18
# or: 17
# is: 15
# one: 15
# the: 14
# event: 14
#
# Average of duplicated words (≥5 reps): 3.49
#
# ================================= Topic: Chief Executive Officer =================================
# and: 31
# to: 24
# customer: 20
# if: 17
# regulatory: 15
# risk: 14
# for: 13
# scope: 12
# recall: 11
# vs: 11
#
# Average of duplicated words (≥5 reps): 2.07
#
# ================================= Topic: study planner =================================
# course: 73
# min: 65
# deep: 36
# day: 35
# week: 31
# and: 29
# weekly: 29
# blocks: 27
# retrieval: 24
# to: 23
#
# Average of duplicated words (≥5 reps): 4.74
#
# ================================= Topic: Recruiter =================================
# target: 20
# role: 19
# to: 16
# summary: 13
# bullets: 12
# and: 12
# impact: 11
# tech: 10
# experience: 10
# time: 10
#
# Average of duplicated words (≥5 reps): 2.68
#
# ================================= Topic: Life Coach =================================
# stress: 32
# after: 30
# sleep: 25
# to: 24
# min: 18
# caffeine: 15
# walk: 15
# work: 15
# wake: 14
# top: 13
#
# Average of duplicated words (≥5 reps): 3.72
#
# ================================= Topic: Etymologist =================================
# pizza: 35
# to: 30
# th: 29
# the: 26
# italian: 24
# bite: 18
# in: 17
# latin: 16
# flatbread: 16
# southern: 15
#
# Average of duplicated words (≥5 reps): 3.72
#
# ================================= Topic: Commentariat =================================
# and: 54
# heat: 38
# clean: 24
# to: 22
# is: 16
# with: 16
# climate: 15
# the: 15
# power: 15
# carbon: 15
#
# Average of duplicated words (≥5 reps): 3.36
#
# ================================= Topic: Magician =================================
# watch: 38
# the: 36
# and: 24
# vanish: 22
# in: 15
# silk: 14
# reveal: 13
# time: 13
# cloth: 13
# your: 12
#
# Average of duplicated words (≥5 reps): 3.20
#
# ================================= Topic: Career Counselor =================================
# and: 28
# cloud: 26
# security: 26
# data: 24
# weeks: 24
# with: 20
# basics: 19
# track: 18
# devops: 17
# or: 17
#
# Average of duplicated words (≥5 reps): 4.01
#
# ================================= Topic: Pet Behaviorist =================================
# distance: 25
# to: 22
# leash: 21
# muzzle: 21
# and: 19
# triggers: 17
# at: 17
# week: 17
# body: 16
# trigger: 16
#
# Average of duplicated words (≥5 reps): 3.75
#
# ================================= Topic: Personal Trainer =================================
# min: 67
# or: 32
# week: 31
# strength: 25
# squat: 22
# zone: 20
# row: 20
# walk: 20
# day: 19
# cardio: 17
#
# Average of duplicated words (≥5 reps): 4.72
#
# ================================= Topic: Mental Health Adviser =================================
# you: 86
# or: 85
# and: 80
# to: 64
# for: 53
# if: 51
# one: 51
# can: 41
# plan: 38
# day: 36
#
# Average of duplicated words (≥5 reps): 3.92
#
# ================================= Topic: Real Estate Agent =================================
# and: 84
# to: 46
# or: 39
# you: 38
# the: 34
# single: 32
# houses: 30
# in: 25
# story: 23
# search: 22
#
# Average of duplicated words (≥5 reps): 3.24
#
# ================================= Topic: Logistician =================================
# and: 88
# for: 62
# or: 62
# you: 41
# venue: 35
# event: 33
# budget: 32
# av: 30
# to: 27
# plan: 27
#
# Average of duplicated words (≥5 reps): 3.43
#
# ================================= Topic: Dentist =================================
# or: 107
# and: 73
# you: 71
# to: 65
# if: 56
# the: 46
# for: 44
# can: 39
# sensitivity: 37
# pain: 32
#
# Average of duplicated words (≥5 reps): 4.28
#
# ================================= Topic: Web Design Consultant =================================
# for: 105
# and: 95
# product: 84
# or: 58
# checkout: 45
# shopify: 44
# to: 38
# next: 37
# cart: 29
# custom: 28
#
# Average of duplicated words (≥5 reps): 3.76
#
# ================================= Topic: AI Assisted Doctor =================================
# pain: 49
# or: 41
# and: 39
# ai: 31
# can: 30
# for: 28
# in: 27
# causes: 27
# abdominal: 25
# imaging: 24
#
# Average of duplicated words (≥5 reps): 4.03
#
# ================================= Topic: Doctor =================================
# and: 120
# for: 96
# if: 58
# pain: 55
# to: 51
# or: 48
# with: 45
# risk: 31
# inflammatory: 29
# week: 25
#
# Average of duplicated words (≥5 reps): 3.90
#
# ================================= Topic: Accountant =================================
# and: 84
# to: 82
# or: 50
# for: 34
# of: 25
# in: 25
# tax: 23
# business: 21
# term: 21
# reduce: 20
#
# Average of duplicated words (≥5 reps): 3.45
#
# ================================= Topic: Chef =================================
# and: 84
# for: 40
# or: 30
# vegetables: 22
# protein: 20
# of: 20
# you: 19
# in: 17
# fiber: 16
# add: 16
#
# Average of duplicated words (≥5 reps): 3.65
#
# ================================= Topic: Automobile Mechanic =================================
# the: 76
# or: 67
# and: 52
# if: 50
# fuel: 47
# starter: 43
# battery: 40
# to: 35
# ignition: 33
# is: 32
#
# Average of duplicated words (≥5 reps): 6.38

# %% [markdown]
# #### Without stopword

# %%
non_stopword_freq_df = non_stopword_df[['acts', 'response']]
topics = non_stopword_freq_df['acts'].unique()

for topic in topics:
    all_words = []
    responses = non_stopword_freq_df[non_stopword_freq_df['acts'] == topic]['response']
    for tokens in responses:
        all_words.extend(tokens)

    word_counts = {}
    for word in all_words:
        if word in word_counts:
            word_counts[word] += 1
        else:
            word_counts[word] = 1
        
    print(f"\n================================= Topic: {topic} =================================")
    for word in sorted(word_counts, key=word_counts.get, reverse=True)[:10]:
        if word_counts[word] >= 5:
            print(f"{word}: {word_counts[word]}")
        else:
            continue
    if word_counts:
        avg_repetition = sum(word_counts.values()) / len(word_counts)
        print(f"\nAverage of duplicated words (≥5 reps): {avg_repetition:.2f}")
    else:
        print("\nNo words repeated ≥ 5 times.")
# Out:
# ================================= Topic: Tech Writer =================================
# app: 74
# download: 58
# screenshot: 57
# install: 49
# run: 45
# click: 39
# linux: 38
# open: 35
# windows: 34
# installer: 34
#
# Average of duplicated words (≥5 reps): 5.71
#
# ================================= Topic: Film Critic =================================
# action: 19
# film: 13
# matrix: 10
# reality: 10
# effects: 10
# concept: 9
# neo: 9
# exposition: 9
# spectacle: 9
# influential: 8
#
# Average of duplicated words (≥5 reps): 2.82
#
# ================================= Topic: Nutritionist =================================
# tbsp: 29
# salt: 21
# quinoa: 18
# olive: 17
# oil: 17
# tahini: 17
# pepper: 16
# tsp: 16
# cooked: 14
# sweet: 14
#
# Average of duplicated words (≥5 reps): 5.02
#
# ================================= Topic: Babysitter =================================
# bedtime: 15
# snack: 13
# simple: 13
# calm: 13
# quiet: 13
# rules: 12
# dinner: 12
# use: 11
# authorized: 11
# parents: 10
#
# Average of duplicated words (≥5 reps): 3.53
#
# ================================= Topic: Makeup Artist =================================
# cream: 35
# apply: 23
# soft: 20
# hydrating: 18
# skin: 15
# satin: 14
# lashes: 14
# lift: 13
# brown: 13
# liner: 13
#
# Average of duplicated words (≥5 reps): 4.01
#
# ================================= Topic: Public Speaking Coach =================================
# opening: 21
# use: 20
# script: 17
# run: 17
# stage: 15
# one: 15
# rehearsal: 15
# slides: 14
# core: 13
# short: 13
#
# Average of duplicated words (≥5 reps): 3.61
#
# ================================= Topic: Digital Art Gallery Guide =================================
# room: 27
# curator: 21
# works: 19
# text: 19
# audio: 18
# mvp: 18
# material: 17
# artist: 17
# event: 17
# media: 16
#
# Average of duplicated words (≥5 reps): 3.61
#
# ================================= Topic: Journalist =================================
# cities: 25
# air: 23
# pollution: 16
# health: 15
# policy: 15
# data: 14
# transport: 13
# urban: 12
# public: 11
# city: 9
#
# Average of duplicated words (≥5 reps): 1.76
#
# ================================= Topic: Spoken English Teacher and Improver =================================
# first: 11
# question: 11
# ill: 6
# correct: 6
# ask: 6
# natural: 6
# heres: 5
# answer: 5
#
# Average of duplicated words (≥5 reps): 2.15
#
# ================================= Topic: Travel Guide =================================
# museum: 52
# galata: 39
# modern: 31
# istanbul: 24
# min: 24
# museums: 22
# day: 22
# cukurcuma: 21
# innocence: 19
# pera: 16
#
# Average of duplicated words (≥5 reps): 4.43
#
# ================================= Topic: Advertiser =================================
# focus: 36
# sampling: 30
# campus: 28
# creative: 26
# social: 23
# influencer: 23
# study: 21
# voltive: 20
# product: 19
# paid: 19
#
# Average of duplicated words (≥5 reps): 3.22
#
# ================================= Topic: Salesperson =================================
# free: 10
# day: 8
# trial: 8
# time: 7
# route: 6
# calling: 5
# smart: 5
#
# Average of duplicated words (≥5 reps): 1.93
#
# ================================= Topic: Wisdom Generator =================================
# one: 61
# weekly: 20
# micro: 18
# day: 18
# week: 13
# daily: 13
# minute: 13
# use: 12
# days: 11
# idea: 11
#
# Average of duplicated words (≥5 reps): 3.33
#
# ================================= Topic: Storyteller =================================
# small: 9
# lantern: 9
# new: 8
# glass: 7
# first: 7
# learned: 7
# would: 6
# like: 6
# time: 6
# kept: 6
#
# Average of duplicated words (≥5 reps): 1.54
#
# ================================= Topic: Football Commentator =================================
# united: 32
# chelsea: 31
# midfield: 16
# quick: 13
# set: 13
# back: 13
# full: 12
# backs: 12
# press: 12
# tactical: 11
#
# Average of duplicated words (≥5 reps): 2.76
#
# ================================= Topic: Stand-up Comedian =================================
# like: 12
# politics: 8
# campaign: 6
# people: 6
# chance: 6
# everyone: 5
# promises: 5
# one: 5
# agree: 5
#
# Average of duplicated words (≥5 reps): 1.56
#
# ================================= Topic: Motivational Coach =================================
# min: 26
# exam: 23
# practice: 22
# day: 20
# session: 17
# study: 16
# review: 16
# one: 15
# plan: 14
# daily: 13
#
# Average of duplicated words (≥5 reps): 3.61
#
# ================================= Topic: Restaurant Owner =================================
# method: 41
# ingredients: 35
# lime: 30
# cilantro: 30
# tortillas: 30
# tacos: 29
# serve: 25
# pork: 24
# onion: 22
# menu: 21
#
# Average of duplicated words (≥5 reps): 5.12
#
# ================================= Topic: Debater =================================
# node: 45
# deno: 40
# native: 25
# ecosystem: 23
# edge: 23
# security: 22
# typescript: 18
# services: 17
# tooling: 17
# modern: 16
#
# Average of duplicated words (≥5 reps): 3.24
#
# ================================= Topic: Debate Coach =================================
# day: 42
# min: 40
# easy: 34
# rebuttal: 28
# evidence: 24
# end: 21
# arguments: 20
# pm: 20
# practice: 19
# one: 19
#
# Average of duplicated words (≥5 reps): 3.72
#
# ================================= Topic: Screenwriter =================================
# julien: 37
# marc: 30
# noura: 27
# elise: 24
# theo: 21
# paris: 19
# anais: 19
# act: 18
# love: 14
# eloise: 14
#
# Average of duplicated words (≥5 reps): 1.96
#
# ================================= Topic: Novelist =================================
# mara: 20
# ilya: 19
# act: 18
# city: 18
# said: 15
# night: 14
# audit: 13
# memory: 13
# future: 12
# like: 12
#
# Average of duplicated words (≥5 reps): 1.74
#
#  =================================Topic: Movie Critic
# film: 11
# feel: 11
# interstellar: 8
# like: 8
# human: 8
# score: 8
# time: 7
# love: 7
# cosmic: 7
# scale: 7
#
# Average of duplicated words (≥5 reps): 1.67
#
#  =================================Topic: Relationship Coach
# one: 24
# time: 12
# use: 12
# need: 10
# check: 9
# minute: 9
# specific: 9
# minutes: 8
# repair: 8
# try: 8
#
# Average of duplicated words (≥5 reps): 1.99
#
# ================================= Topic: Poet =================================
# like: 6
# love: 5
# hand: 5
# light: 5
#
# Average of duplicated words (≥5 reps): 1.36
#
#  =================================Topic: Rapper
# hook: 29
# every: 14
# im: 13
# beat: 12
# iron: 12
# verse: 12
# found: 12
# turned: 11
# like: 11
# aint: 11
#
# Average of duplicated words (≥5 reps): 2.13
#
#  =================================Topic: Motivational Speaker
# one: 18
# small: 8
# keep: 8
# every: 7
# progress: 7
# next: 7
# step: 7
# today: 6
# line: 5
# stop: 5
#
# Average of duplicated words (≥5 reps): 1.64
#
#  =================================Topic: Philosophy Teacher
# example: 32
# ask: 23
# would: 22
# care: 17
# practice: 15
# ethics: 13
# control: 13
# everyday: 12
# virtue: 12
# lenses: 11
#
# Average of duplicated words (≥5 reps): 2.24
#
# ================================= Topic: Philosopher =================================
# decision: 26
# rights: 26
# options: 19
# fairness: 16
# review: 16
# option: 14
# stakeholders: 13
# duties: 12
# harms: 12
# ethical: 11
#
# Average of duplicated words (≥5 reps): 2.33
#
#  =================================Topic: Math Teacher
# probability: 32
# outcomes: 23
# one: 15
# event: 14
# events: 14
# step: 14
# replacement: 13
# independent: 12
# bayes: 12
# without: 12
#
# Average of duplicated words (≥5 reps): 3.03
#
# ================================= Topic: Chief Executive Officer =================================
# customer: 20
# regulatory: 15
# risk: 14
# scope: 12
# recall: 11
# vs: 11
# next: 11
# progress: 10
# product: 9
# severity: 8
#
# Average of duplicated words (≥5 reps): 1.90
#
# ================================= Topic: study planner =================================
# course: 73
# min: 65
# deep: 36
# day: 35
# week: 31
# weekly: 29
# blocks: 27
# retrieval: 24
# project: 22
# work: 20
#
# Average of duplicated words (≥5 reps): 4.60
#
# ================================= Topic: Recruiter =================================
# target: 20
# role: 19
# summary: 13
# bullets: 12
# impact: 11
# tech: 10
# experience: 10
# time: 10
# core: 9
# skills: 9
#
# Average of duplicated words (≥5 reps): 2.61
#
# ================================= Topic: Life Coach =================================
# stress: 32
# sleep: 25
# min: 18
# caffeine: 15
# walk: 15
# work: 15
# wake: 14
# top: 13
# time: 12
# habit: 12
#
# Average of duplicated words (≥5 reps): 3.53
#
# ================================= Topic: Etymologist =================================
# pizza: 35
# th: 29
# italian: 24
# bite: 18
# latin: 16
# flatbread: 16
# southern: 15
# baked: 15
# pitta: 15
# germanic: 15
#
# Average of duplicated words (≥5 reps): 3.41
#
# ================================= Topic: Commentariat =================================
# heat: 38
# clean: 24
# climate: 15
# power: 15
# carbon: 15
# management: 13
# energy: 12
# methane: 12
# flood: 11
# plans: 11
#
# Average of duplicated words (≥5 reps): 3.09
#
# ================================= Topic: Magician =================================
# watch: 38
# vanish: 22
# silk: 14
# reveal: 13
# time: 13
# cloth: 13
# envelope: 11
# audience: 9
# wrap: 9
# empty: 9
#
# Average of duplicated words (≥5 reps): 2.89
#
# ================================= Topic: Career Counselor =================================
# cloud: 26
# security: 26
# data: 24
# weeks: 24
# basics: 19
# track: 18
# devops: 17
# tests: 17
# backend: 16
# stack: 16
#
# Average of duplicated words (≥5 reps): 3.95
#
# ================================= Topic: Pet Behaviorist =================================
# distance: 25
# leash: 21
# muzzle: 21
# triggers: 17
# week: 17
# body: 16
# trigger: 16
# avoid: 15
# training: 13
# short: 12
#
# Average of duplicated words (≥5 reps): 3.52
#
# ================================= Topic: Personal Trainer =================================
# min: 67
# week: 31
# strength: 25
# squat: 22
# zone: 20
# row: 20
# walk: 20
# day: 19
# cardio: 17
# kg: 15
#
# Average of duplicated words (≥5 reps): 4.70
#
# ================================= Topic: Mental Health Adviser =================================
# one: 51
# plan: 38
# day: 36
# mood: 31
# thought: 30
# small: 29
# minute: 28
# call: 26
# safety: 24
# help: 22
#
# Average of duplicated words (≥5 reps): 3.19
#
# ================================= Topic: Real Estate Agent =================================
# single: 32
# houses: 30
# story: 23
# search: 22
# downtown: 17
# floor: 17
# garden: 14
# central: 14
# need: 13
# low: 13
#
# Average of duplicated words (≥5 reps): 2.69
#
# ================================= Topic: Logistician =================================
# venue: 35
# event: 33
# budget: 32
# av: 30
# plan: 27
# need: 21
# catering: 21
# date: 18
# venues: 17
# person: 17
#
# Average of duplicated words (≥5 reps): 2.97
#
# ================================= Topic: Dentist =================================
# sensitivity: 37
# pain: 32
# toothpaste: 32
# dentist: 31
# cold: 29
# use: 29
# fluoride: 29
# dental: 27
# avoid: 25
# care: 22
#
# Average of duplicated words (≥5 reps): 3.34
#
# ================================= Topic: Web Design Consultant =================================
# product: 84
# checkout: 45
# shopify: 44
# next: 37
# cart: 29
# custom: 28
# shipping: 28
# payments: 25
# high: 24
# commerce: 24
#
# Average of duplicated words (≥5 reps): 3.48
#
# ================================= Topic: AI Assisted Doctor =================================
# pain: 49
# ai: 31
# causes: 27
# abdominal: 25
# imaging: 24
# severe: 21
# bowel: 17
# appendicitis: 17
# blood: 16
# obstruction: 14
#
# Average of duplicated words (≥5 reps): 3.55
#
# ================================= Topic: Doctor =================================
# pain: 55
# risk: 31
# inflammatory: 29
# week: 25
# plan: 24
# review: 24
# supplements: 23
# safety: 22
# joint: 22
# medication: 21
#
# Average of duplicated words (≥5 reps): 3.42
#
# ================================= Topic: Accountant =================================
# tax: 23
# business: 21
# term: 21
# reduce: 20
# long: 19
# growth: 19
# costs: 17
# savings: 15
# investments: 15
# financial: 14
#
# Average of duplicated words (≥5 reps): 2.86
#
# ================================= Topic: Chef =================================
# vegetables: 22
# protein: 20
# fiber: 16
# add: 16
# oil: 13
# quick: 12
# light: 12
# chickpeas: 12
# cost: 12
# healthy: 12
#
# Average of duplicated words (≥5 reps): 3.13
#
# ================================= Topic: Automobile Mechanic =================================
# fuel: 47
# starter: 43
# battery: 40
# ignition: 33
# engine: 31
# pump: 24
# action: 24
# cause: 19
# switch: 19
# replace: 18
#
# Average of duplicated words (≥5 reps): 5.51
