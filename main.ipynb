# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import re
from nltk.tokenize import word_tokenize
import unicodedata
import nltk

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Sawitt\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Sawitt\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ### Download dataset

# %%
df = pd.read_csv("temp.csv")

df.head()
# Out:
#    index                     acts  \
# 0    151  Chief Executive Officer
# 1    152  Chief Executive Officer
# 2    153  Chief Executive Officer
# 3    154  Chief Executive Officer
# 4    155  Chief Executive Officer
#
#                                               prompt  \
# 0  I want you to act as a Chief Executive Officer...
# 1  I want you to act as a Chief Executive Officer...
# 2  I want you to act as a Chief Executive Officer...
# 3  I want you to act as a Chief Executive Officer...
# 4  I want you to act as a Chief Executive Officer...
#
#                                             response  Word count  Grammar  \
# 0  I’m structuring a crisis-response execution pl...         578       86
# 1  Team assembled. Moving to in‑progress risk ass...         223       90
# 2  I’ll update the recall plan to reflect progres...         114       98
# 3  Distribution halt completed; moving through re...         398       86
# 4  Progress:\n- Regulatory notifications complete...         115       90
#
#    Fluency  Clarity  Engagement  Overall Score AI Similarity  Sources Found  \
# 0       46       73          74             69           88%              2
# 1       40       66          78             67           81%              0
# 2       68       74          76             80           83%              0
# 3       44       71          74             68           90%              0
# 4       45       77          77             71           96%              0
#
#   Overall Plagiarism Score
# 0                       8%
# 1                       0%
# 2                       0%
# 3                       0%
# 4                       0%

# %% [markdown]
# ### Check dataframe information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     50 non-null     int64
#  1   acts                      50 non-null     object
#  2   prompt                    50 non-null     object
#  3   response                  50 non-null     object
#  4   Word count                50 non-null     int64
#  5   Grammar                   50 non-null     int64
#  6   Fluency                   50 non-null     int64
#  7   Clarity                   50 non-null     int64
#  8   Engagement                50 non-null     int64
#  9   Overall Score             50 non-null     int64
#  10  AI Similarity             50 non-null     object
#  11  Sources Found             50 non-null     int64
#  12  Overall Plagiarism Score  50 non-null     object
# dtypes: int64(8), object(5)
# memory usage: 5.2+ KB

# %%
non_stopword_df = df.copy()

non_stopword_df.head()
# Out:
#    index                     acts  \
# 0    151  Chief Executive Officer
# 1    152  Chief Executive Officer
# 2    153  Chief Executive Officer
# 3    154  Chief Executive Officer
# 4    155  Chief Executive Officer
#
#                                               prompt  \
# 0  I want you to act as a Chief Executive Officer...
# 1  I want you to act as a Chief Executive Officer...
# 2  I want you to act as a Chief Executive Officer...
# 3  I want you to act as a Chief Executive Officer...
# 4  I want you to act as a Chief Executive Officer...
#
#                                             response  Word count  Grammar  \
# 0  I’m structuring a crisis-response execution pl...         578       86
# 1  Team assembled. Moving to in‑progress risk ass...         223       90
# 2  I’ll update the recall plan to reflect progres...         114       98
# 3  Distribution halt completed; moving through re...         398       86
# 4  Progress:\n- Regulatory notifications complete...         115       90
#
#    Fluency  Clarity  Engagement  Overall Score AI Similarity  Sources Found  \
# 0       46       73          74             69           88%              2
# 1       40       66          78             67           81%              0
# 2       68       74          76             80           83%              0
# 3       44       71          74             68           90%              0
# 4       45       77          77             71           96%              0
#
#   Overall Plagiarism Score
# 0                       8%
# 1                       0%
# 2                       0%
# 3                       0%
# 4                       0%

# %% [markdown]
# ### Data Cleaning

# %%
def clean_text(text):
    # Convert to lowercase
    if isinstance(text, str):
        text = text.lower()
        return text
    return text

def clean_punctuation(text):
    # Remove punctuation characters
    if isinstance(text, str):
        text = re.sub(r'’', '', text)
        text = re.sub(r'[^\s\w]', ' ', text)
        text = re.sub(r'\n', ' ', text)
        text = re.sub(r'[^\D]', ' ', text)
        text = re.sub(r'\b[a-zA-Z]\b', '', text)
        return text
    return text

def normalize_characters(text):
    if isinstance(text, str):
        normalized_text = unicodedata.normalize('NFKD', text).encode('ASCII', 'ignore').decode('utf-8')
        return normalized_text
    return text

def remove_stopword(text):
    stopwords = set(nltk.corpus.stopwords.words('english'))
    filtered_words = [word for word in text.split() if word not in stopwords]
    return ' '.join(filtered_words)

# %%
df['response'] = df['response'].apply(clean_text).apply(clean_punctuation).apply(normalize_characters)

non_stopword_df['response'] = non_stopword_df['response'].apply(clean_text).apply(clean_punctuation).apply(normalize_characters).apply(remove_stopword)

# %%
df['response'].head()
# Out:
# 0    im structuring  crisis response execution plan...
# 1    team assembled  moving to in progress risk ass...
# 2    ill update the recall plan to reflect progress...
# 3    distribution halt completed  moving through re...
# 4    progress    regulatory notifications completed...
# Name: response, dtype: object

# %%
non_stopword_df['response'].head()
# Out:
# 0    im structuring crisis response execution plan ...
# 1    team assembled moving progress risk assessment...
# 2    ill update recall plan reflect progress comple...
# 3    distribution halt completed moving regulatory ...
# 4    progress regulatory notifications completed sc...
# Name: response, dtype: object

# %% [markdown]
# ### Data Preprocessing

# %%
df['response'] = df['response'].apply(word_tokenize)

# %%
non_stopword_df['response'] = non_stopword_df['response'].apply(
    lambda x: word_tokenize(x) if isinstance(x, str) else x
)

# %% [markdown]
# ### Word Frequencies

# %% [markdown]
# #### With stopwords

# %%
freq_df = df[['acts', 'response']]
topics = freq_df['acts'].unique()

for topic in topics:
    all_words = []
    responses = freq_df[freq_df['acts'] == topic]['response']
    for tokens in responses:
        all_words.extend(tokens)

    word_counts = {}
    for word in all_words:
        if word in word_counts:
            word_counts[word] += 1
        else:
            word_counts[word] = 1
        
    print(f"\n================================= Topic: {topic} =================================")
    for word in sorted(word_counts, key=word_counts.get, reverse=True):
        if word_counts[word] >= 5:
            print(f"{word}: {word_counts[word]}")
        else:
            continue
    if word_counts:
        avg_repetition = sum(word_counts.values()) / len(word_counts)
        print(f"\nAverage of duplicated words (≥5 reps): {avg_repetition:.2f}")
    else:
        print("\nNo words repeated ≥ 5 times.")
# Out:
# ================================= Topic: Chief Executive Officer =================================
# and: 31
# to: 24
# customer: 20
# if: 17
# regulatory: 15
# risk: 14
# for: 13
# scope: 12
# recall: 11
# vs: 11
# in: 11
# next: 11
# progress: 10
# product: 9
# the: 8
# severity: 8
# safety: 8
# legal: 7
# supplier: 7
# draft: 7
# or: 7
# incident: 6
# defect: 6
# any: 6
# initial: 6
# notice: 6
# replacement: 6
# with: 6
# release: 6
# you: 6
# notifications: 6
# hours: 5
# decision: 5
# log: 5
# inventory: 5
# production: 5
# data: 5
# lot: 5
# serial: 5
# full: 5
# cost: 5
# matrix: 5
# update: 5
# of: 5
# refund: 5
# launch: 5
# landing: 5
# page: 5
# faq: 5
# logistics: 5
# units: 5
# audit: 5
# messaging: 5
# actions: 5
# distribution: 5
# completed: 5
# ill: 5
# assessment: 5
# halt: 5
#
# Average of duplicated words (≥5 reps): 2.07
#
# ================================= Topic: study planner =================================
# course: 73
# min: 65
# deep: 36
# day: 35
# week: 31
# and: 29
# weekly: 29
# blocks: 27
# retrieval: 24
# to: 23
# project: 22
# work: 20
# am: 20
# pm: 20
# courses: 17
# study: 16
# plan: 16
# evening: 16
# tasks: 16
# sleep: 16
# hours: 15
# time: 14
# block: 14
# review: 13
# for: 13
# recall: 13
# past: 13
# off: 13
# per: 13
# your: 12
# you: 12
# buffer: 12
# practice: 12
# outline: 12
# light: 12
# stress: 12
# out: 12
# draft: 11
# days: 11
# planning: 11
# problem: 11
# ill: 10
# fixed: 10
# if: 10
# sprint: 10
# flashcards: 10
# mixed: 10
# no: 10
# build: 9
# with: 9
# in: 9
# dates: 9
# energy: 9
# best: 9
# set: 9
# problems: 9
# impact: 9
# focus: 9
# well: 9
# being: 9
# movement: 9
# weeks: 9
# by: 8
# schedule: 8
# next: 8
# exam: 8
# availability: 8
# topics: 8
# after: 8
# daily: 8
# sets: 8
# reading: 8
# weight: 8
# key: 7
# times: 7
# sun: 7
# spaced: 7
# prep: 7
# questions: 7
# or: 7
# academic: 7
# grade: 7
# cumulative: 7
# add: 7
# new: 6
# inputs: 6
# deadlines: 6
# each: 6
# break: 6
# admin: 6
# template: 6
# low: 6
# into: 6
# one: 6
# mid: 6
# missed: 6
# first: 5
# list: 5
# baseline: 5
# provide: 5
# tailor: 5
# commitments: 5
# long: 5
# rotate: 5
# pre: 5
# class: 5
# slides: 5
# papers: 5
# deliverables: 5
# revise: 5
# notes: 5
# example: 5
# mon: 5
# tue: 5
# wed: 5
# thu: 5
# fri: 5
# weakest: 5
# sat: 5
# micro: 5
# targets: 5
# lectures: 5
# chapters: 5
# outputs: 5
# quiz: 5
# learn: 5
# quick: 5
# due: 5
# wake: 5
# site: 5
# phone: 5
# recovery: 5
# credit: 5
# longest: 5
# score: 5
# high: 5
# actual: 5
#
# Average of duplicated words (≥5 reps): 4.74
#
# ================================= Topic: Recruiter =================================
# target: 20
# role: 19
# to: 16
# summary: 13
# bullets: 12
# and: 12
# impact: 11
# tech: 10
# experience: 10
# time: 10
# if: 9
# core: 9
# skills: 9
# data: 9
# achievements: 8
# scope: 8
# tools: 8
# scale: 8
# education: 8
# certifications: 8
# python: 8
# top: 7
# keywords: 7
# tailor: 6
# industry: 6
# metrics: 6
# tool: 6
# header: 6
# verb: 6
# reduced: 6
# years: 6
# cloud: 6
# optimized: 6
# key: 6
# provide: 5
# title: 5
# immediate: 5
# name: 5
# email: 5
# linkedin: 5
# github: 5
# phone: 5
# quantified: 5
# grouped: 5
# analytics: 5
# avoid: 5
# soft: 5
# skill: 5
# bullet: 5
# strong: 5
# alignment: 5
# what: 5
# how: 5
# measurable: 5
# architected: 5
# consolidated: 5
# send: 5
# jd: 5
#
# Average of duplicated words (≥5 reps): 2.68
#
# ================================= Topic: Life Coach =================================
# stress: 32
# after: 30
# sleep: 25
# to: 24
# min: 18
# caffeine: 15
# walk: 15
# work: 15
# __: 15
# wake: 14
# top: 13
# time: 12
# if: 12
# habit: 12
# trigger: 11
# and: 10
# body: 10
# signal: 10
# for: 10
# on: 10
# triggers: 10
# breath: 10
# journal: 10
# weeks: 10
# no: 10
# ____: 10
# daily: 9
# minutes: 9
# minute: 9
# or: 9
# water: 9
# am: 9
# pm: 9
# habits: 8
# phone: 8
# inhale: 7
# focus: 7
# times: 7
# only: 7
# before: 7
# last: 7
# low: 7
# use: 6
# lights: 6
# dim: 6
# screens: 6
# breathing: 6
# it: 6
# reset: 6
# day: 6
# bed: 6
# your: 6
# baseline: 5
# days: 5
# twice: 5
# micro: 5
# laptop: 5
# physiological: 5
# sighs: 5
# exhale: 5
# lunch: 5
# page: 5
# brain: 5
# dump: 5
# box: 5
# grounding: 5
# label: 5
# feel: 5
# cold: 5
# face: 5
# wrists: 5
# environment: 5
# modes: 5
# calendar: 5
# batch: 5
# weekly: 5
# same: 5
# review: 5
# shrink: 5
# sentence: 5
# add: 5
# anchors: 5
# fixed: 5
# cool: 5
# room: 5
# boundaries: 5
# hrs: 5
# persistent: 5
# insomnia: 5
# panic: 5
# mood: 5
# professional: 5
# tailor: 5
# provide: 5
# cues: 5
# social: 5
# log: 5
#
# Average of duplicated words (≥5 reps): 3.77
#
# ================================= Topic: Etymologist =================================
# pizza: 35
# to: 30
# th: 29
# the: 26
# italian: 24
# bite: 18
# in: 17
# latin: 16
# flatbread: 16
# southern: 15
# baked: 15
# pitta: 15
# germanic: 15
# greek: 14
# is: 13
# from: 12
# medieval: 12
# english: 12
# pizzo: 11
# meaning: 11
# term: 11
# tomato: 11
# piza: 10
# as: 10
# flat: 10
# pressed: 10
# or: 10
# early: 10
# naples: 10
# with: 10
# of: 9
# for: 9
# pinsa: 9
# topped: 9
# form: 9
# italy: 8
# semantic: 8
# pinsere: 7
# modern: 7
# post: 7
# rounds: 6
# lombardic: 6
# piece: 6
# and: 6
# morsel: 6
# sense: 6
# bread: 6
# etymology: 5
# earliest: 5
# ce: 5
# charter: 5
# gaeta: 5
# tithe: 5
# pissa: 5
# central: 5
# pound: 5
# press: 5
# vulgar: 5
# byzantine: 5
# pita: 5
# borrowed: 5
# bizzo: 5
# proto: 5
# bitana: 5
# round: 5
# toppings: 5
# narrows: 5
# yeasted: 5
# columbian: 5
# becomes: 5
# later: 5
# word: 5
# wwii: 5
# singular: 5
# plural: 5
# pizze: 5
# pizzeria: 5
# summary: 5
# likely: 5
# that: 5
# century: 5
# into: 5
#
# Average of duplicated words (≥5 reps): 3.72
#
# ================================= Topic: Commentariat =================================
# and: 54
# heat: 38
# clean: 24
# to: 22
# is: 16
# with: 16
# climate: 15
# the: 15
# power: 15
# carbon: 15
# management: 13
# in: 13
# energy: 12
# methane: 12
# flood: 11
# for: 11
# plans: 11
# risk: 10
# grid: 10
# electrify: 10
# pumps: 10
# change: 9
# wildfire: 9
# smoke: 9
# insurance: 9
# industrial: 9
# efficiency: 9
# of: 9
# infrastructure: 8
# cost: 8
# low: 8
# high: 8
# action: 8
# equity: 7
# set: 7
# what: 7
# permitting: 7
# end: 7
# evs: 7
# induction: 7
# insulation: 7
# or: 7
# public: 7
# reform: 7
# green: 7
# electricity: 7
# cut: 7
# now: 7
# term: 6
# temperature: 6
# gas: 6
# building: 6
# choose: 6
# standards: 6
# access: 6
# early: 6
# measure: 6
# resilience: 6
# health: 6
# exposure: 6
# not: 5
# clear: 5
# more: 5
# scalable: 5
# why: 5
# it: 5
# matters: 5
# impact: 5
# losses: 5
# supply: 5
# chain: 5
# costs: 5
# works: 5
# near: 5
# solar: 5
# wind: 5
# storage: 5
# demand: 5
# uses: 5
# medium: 5
# oil: 5
# capture: 5
# landfill: 5
# fast: 5
# controls: 5
# efficient: 5
# based: 5
# mrv: 5
# policy: 5
# pricing: 5
# durable: 5
# grids: 5
# land: 5
# use: 5
# procurement: 5
# just: 5
# transition: 5
# reskilling: 5
# reduce: 5
# adaptation: 5
# cooling: 5
# urban: 5
# updated: 5
# maps: 5
# zoning: 5
# resilient: 5
# scope: 5
# targets: 5
# ppas: 5
# tariffs: 5
# supplier: 5
# engagement: 5
# optimization: 5
# as: 5
# replace: 5
# when: 5
# food: 5
# waste: 5
# build: 5
# manage: 5
# residual: 5
# execution: 5
# from: 5
# natural: 5
#
# Average of duplicated words (≥5 reps): 3.36
#
# ================================= Topic: Magician =================================
# watch: 38
# the: 36
# and: 24
# vanish: 22
# in: 15
# silk: 14
# reveal: 13
# time: 13
# cloth: 13
# your: 12
# envelope: 11
# from: 11
# own: 10
# then: 10
# audience: 9
# wrap: 9
# empty: 9
# or: 8
# use: 8
# no: 8
# impossible: 8
# safe: 7
# show: 7
# isolate: 7
# misdirection: 7
# set: 7
# it: 7
# consent: 6
# prop: 6
# hank: 6
# box: 6
# you: 6
# teach: 5
# steals: 5
# based: 5
# with: 5
# for: 5
# inexpensive: 5
# devils: 5
# change: 5
# bag: 5
# handling: 5
# sealed: 5
# have: 5
# flies: 5
# tips: 5
# exposed: 5
# location: 5
# still: 5
# after: 5
# display: 5
# venue: 5
# size: 5
# runtime: 5
# secret: 5
# before: 5
#
# Average of duplicated words (≥5 reps): 3.20
#
# ================================= Topic: Career Counselor =================================
# and: 28
# cloud: 26
# security: 26
# data: 24
# weeks: 24
# with: 20
# basics: 19
# track: 18
# devops: 17
# or: 17
# tests: 17
# backend: 16
# stack: 16
# design: 16
# week: 16
# ci: 15
# frontend: 14
# for: 14
# language: 14
# github: 14
# full: 13
# azure: 13
# caching: 13
# auth: 13
# system: 12
# issues: 12
# roles: 11
# cd: 11
# ml: 11
# sql: 11
# to: 11
# eng: 11
# python: 10
# sre: 10
# aws: 10
# git: 10
# deploy: 10
# api: 10
# projects: 10
# react: 9
# typescript: 9
# testing: 9
# unit: 9
# integration: 9
# actions: 9
# rest: 9
# metrics: 9
# app: 9
# search: 9
# repos: 9
# engineering: 8
# strong: 8
# internships: 8
# demo: 8
# pagination: 8
# optional: 8
# target: 8
# current: 8
# skills: 8
# time: 8
# plan: 8
# observability: 8
# java: 7
# docker: 7
# one: 7
# month: 7
# small: 7
# jd: 7
# weekly: 7
# tailor: 7
# project: 7
# test: 7
# secure: 7
# concise: 6
# apis: 6
# infra: 6
# platform: 6
# tooling: 6
# but: 6
# entry: 6
# http: 6
# crud: 6
# pipeline: 6
# service: 6
# load: 6
# oss: 6
# prs: 6
# job: 6
# interviews: 6
# geography: 6
# collaboration: 5
# market: 5
# gcp: 5
# ai: 5
# fintech: 5
# healthtech: 5
# hybrid: 5
# apprenticeships: 5
# core: 5
# cs: 5
# structures: 5
# algorithms: 5
# managed: 5
# queues: 5
# cli: 5
# add: 5
# dockerize: 5
# render: 5
# fly: 5
# io: 5
# vercel: 5
# indexes: 5
# capstone: 5
# polish: 5
# portfolio: 5
# readme: 5
# rate: 5
# qualifications: 5
# degree: 5
# not: 5
# certs: 5
# saa: 5
# az: 5
# prep: 5
# resume: 5
# clear: 5
# readmes: 5
# networking: 5
# meetups: 5
# targeted: 5
# referrals: 5
# easy: 5
# medium: 5
# behavioral: 5
# star: 5
# resources: 5
# specs: 5
# interests: 5
# linux: 5
# starter: 5
# jobs: 5
# what: 5
# modeling: 5
#
# Average of duplicated words (≥5 reps): 4.01
#
# ================================= Topic: Pet Behaviorist =================================
# distance: 25
# to: 22
# leash: 21
# muzzle: 21
# and: 19
# triggers: 17
# at: 17
# week: 17
# body: 16
# trigger: 16
# avoid: 15
# with: 15
# training: 13
# short: 12
# greetings: 12
# if: 12
# no: 11
# treat: 11
# early: 11
# calm: 11
# dog: 11
# or: 11
# daily: 11
# conditioning: 10
# recovery: 10
# it: 10
# management: 9
# turn: 9
# reinforce: 9
# food: 9
# any: 9
# bite: 9
# plan: 8
# off: 8
# log: 8
# duration: 8
# time: 8
# threshold: 8
# only: 8
# mat: 8
# before: 8
# walks: 8
# history: 8
# veterinary: 8
# behavior: 8
# intensity: 8
# safety: 7
# for: 7
# check: 7
# name: 7
# target: 7
# cue: 7
# on: 7
# loose: 7
# games: 7
# quiet: 7
# parallel: 7
# escalation: 7
# certified: 7
# professional: 7
# mouth: 6
# rapid: 6
# hand: 6
# scatter: 6
# feed: 6
# walk: 6
# home: 6
# gate: 6
# end: 6
# punishment: 6
# relaxed: 6
# look: 6
# signals: 6
# pain: 5
# orthopedic: 5
# thyroid: 5
# gates: 5
# basket: 5
# positive: 5
# front: 5
# clip: 5
# harness: 5
# assess: 5
# hard: 5
# stare: 5
# below: 5
# settle: 5
# safe: 5
# high: 5
# value: 5
# stays: 5
# pattern: 5
# find: 5
# through: 5
# protocol: 5
# visitors: 5
# pre: 5
# behind: 5
# crate: 5
# stuffed: 5
# kong: 5
# use: 5
# one: 5
# movement: 5
# success: 5
# enrichment: 5
# routine: 5
# puzzles: 5
# reps: 5
# predictable: 5
# arousal: 5
# adequate: 5
# flooding: 5
# uncontrolled: 5
# parks: 5
# consult: 5
# behaviorist: 5
# dacvb: 5
# response: 5
# age: 5
# visitor: 5
#
# Average of duplicated words (≥5 reps): 3.75
#
# ================================= Topic: Personal Trainer =================================
# min: 67
# or: 32
# week: 31
# strength: 25
# squat: 22
# zone: 20
# row: 20
# walk: 20
# day: 19
# cardio: 17
# kg: 15
# mobility: 15
# press: 15
# and: 14
# weeks: 14
# intervals: 14
# push: 14
# carry: 14
# up: 13
# reps: 13
# add: 13
# weight: 13
# weekly: 12
# body: 12
# hinge: 12
# pull: 12
# sleep: 11
# days: 10
# kcal: 10
# if: 10
# protein: 10
# full: 9
# steps: 9
# baseline: 9
# easy: 9
# sets: 9
# hip: 9
# bodyweight: 9
# time: 8
# rest: 8
# leg: 8
# for: 8
# every: 8
# to: 7
# rdl: 7
# single: 7
# deload: 7
# lifts: 7
# pain: 7
# provide: 7
# plan: 6
# current: 6
# loss: 6
# training: 6
# after: 6
# sessions: 6
# session: 6
# split: 6
# core: 6
# progression: 6
# load: 6
# loaded: 6
# age: 5
# injuries: 5
# equipment: 5
# tailor: 5
# goal: 5
# fat: 5
# lb: 5
# per: 5
# structure: 5
# neat: 5
# rpe: 5
# pattern: 5
# goblet: 5
# back: 5
# db: 5
# overhead: 5
# pulldown: 5
# lunge: 5
# top: 5
# of: 5
# range: 5
# then: 5
# volume: 5
# conversational: 5
# bike: 5
# hard: 5
# with: 5
# mon: 5
# tue: 5
# wed: 5
# thu: 5
# fri: 5
# carries: 5
# sat: 5
# longer: 5
# sun: 5
# nutrition: 5
# calorie: 5
# deficit: 5
# by: 5
# fiber: 5
# plate: 5
# lean: 5
# carbs: 5
# healthy: 5
# fats: 5
# ml: 5
# waist: 5
# total: 5
# glute: 5
# bridge: 5
# variations: 5
# band: 5
# inverted: 5
# backpack: 5
# stop: 5
# sharp: 5
# dizziness: 5
# medical: 5
# clearance: 5
# conditions: 5
# tailored: 5
# interval: 5
# incline: 5
# thrust: 5
# light: 5
#
# Average of duplicated words (≥5 reps): 4.72

# %% [markdown]
# #### Without stopword

# %%
non_stopword_freq_df = non_stopword_df[['acts', 'response']]
topics = non_stopword_freq_df['acts'].unique()

for topic in topics:
    all_words = []
    responses = non_stopword_freq_df[non_stopword_freq_df['acts'] == topic]['response']
    for tokens in responses:
        all_words.extend(tokens)

    word_counts = {}
    for word in all_words:
        if word in word_counts:
            word_counts[word] += 1
        else:
            word_counts[word] = 1
        
    print(f"\n================================= Topic: {topic} =================================")
    for word in sorted(word_counts, key=word_counts.get, reverse=True):
        if word_counts[word] >= 5:
            print(f"{word}: {word_counts[word]}")
        else:
            continue
    if word_counts:
        avg_repetition = sum(word_counts.values()) / len(word_counts)
        print(f"\nAverage of duplicated words (≥5 reps): {avg_repetition:.2f}")
    else:
        print("\nNo words repeated ≥ 5 times.")
# Out:
# ================================= Topic: Chief Executive Officer =================================
# customer: 20
# regulatory: 15
# risk: 14
# scope: 12
# recall: 11
# vs: 11
# next: 11
# progress: 10
# product: 9
# severity: 8
# safety: 8
# legal: 7
# supplier: 7
# draft: 7
# incident: 6
# defect: 6
# initial: 6
# notice: 6
# replacement: 6
# release: 6
# notifications: 6
# hours: 5
# decision: 5
# log: 5
# inventory: 5
# production: 5
# data: 5
# lot: 5
# serial: 5
# full: 5
# cost: 5
# matrix: 5
# update: 5
# refund: 5
# launch: 5
# landing: 5
# page: 5
# faq: 5
# logistics: 5
# units: 5
# audit: 5
# messaging: 5
# actions: 5
# distribution: 5
# completed: 5
# ill: 5
# assessment: 5
# halt: 5
#
# Average of duplicated words (≥5 reps): 1.90
#
# ================================= Topic: study planner =================================
# course: 73
# min: 65
# deep: 36
# day: 35
# week: 31
# weekly: 29
# blocks: 27
# retrieval: 24
# project: 22
# work: 20
# pm: 20
# courses: 17
# study: 16
# plan: 16
# evening: 16
# tasks: 16
# sleep: 16
# hours: 15
# time: 14
# block: 14
# review: 13
# recall: 13
# past: 13
# per: 13
# buffer: 12
# practice: 12
# outline: 12
# light: 12
# stress: 12
# draft: 11
# days: 11
# planning: 11
# problem: 11
# ill: 10
# fixed: 10
# sprint: 10
# flashcards: 10
# mixed: 10
# build: 9
# dates: 9
# energy: 9
# best: 9
# set: 9
# problems: 9
# impact: 9
# focus: 9
# well: 9
# movement: 9
# weeks: 9
# schedule: 8
# next: 8
# exam: 8
# availability: 8
# topics: 8
# daily: 8
# sets: 8
# reading: 8
# weight: 8
# key: 7
# times: 7
# sun: 7
# spaced: 7
# prep: 7
# questions: 7
# academic: 7
# grade: 7
# cumulative: 7
# add: 7
# new: 6
# inputs: 6
# deadlines: 6
# break: 6
# admin: 6
# template: 6
# low: 6
# one: 6
# mid: 6
# missed: 6
# first: 5
# list: 5
# baseline: 5
# provide: 5
# tailor: 5
# commitments: 5
# long: 5
# rotate: 5
# pre: 5
# class: 5
# slides: 5
# papers: 5
# deliverables: 5
# revise: 5
# notes: 5
# example: 5
# mon: 5
# tue: 5
# wed: 5
# thu: 5
# fri: 5
# weakest: 5
# sat: 5
# micro: 5
# targets: 5
# lectures: 5
# chapters: 5
# outputs: 5
# quiz: 5
# learn: 5
# quick: 5
# due: 5
# wake: 5
# site: 5
# phone: 5
# recovery: 5
# credit: 5
# longest: 5
# score: 5
# high: 5
# actual: 5
#
# Average of duplicated words (≥5 reps): 4.60
#
# ================================= Topic: Recruiter =================================
# target: 20
# role: 19
# summary: 13
# bullets: 12
# impact: 11
# tech: 10
# experience: 10
# time: 10
# core: 9
# skills: 9
# data: 9
# achievements: 8
# scope: 8
# tools: 8
# scale: 8
# education: 8
# certifications: 8
# python: 8
# top: 7
# keywords: 7
# tailor: 6
# industry: 6
# metrics: 6
# tool: 6
# header: 6
# verb: 6
# reduced: 6
# years: 6
# cloud: 6
# optimized: 6
# key: 6
# provide: 5
# title: 5
# immediate: 5
# name: 5
# email: 5
# linkedin: 5
# github: 5
# phone: 5
# quantified: 5
# grouped: 5
# analytics: 5
# avoid: 5
# soft: 5
# skill: 5
# bullet: 5
# strong: 5
# alignment: 5
# measurable: 5
# architected: 5
# consolidated: 5
# send: 5
# jd: 5
#
# Average of duplicated words (≥5 reps): 2.61
#
# ================================= Topic: Life Coach =================================
# stress: 32
# sleep: 25
# min: 18
# caffeine: 15
# walk: 15
# work: 15
# __: 15
# wake: 14
# top: 13
# time: 12
# habit: 12
# trigger: 11
# body: 10
# signal: 10
# triggers: 10
# breath: 10
# journal: 10
# weeks: 10
# ____: 10
# daily: 9
# minutes: 9
# minute: 9
# water: 9
# pm: 9
# habits: 8
# phone: 8
# inhale: 7
# focus: 7
# times: 7
# last: 7
# low: 7
# use: 6
# lights: 6
# dim: 6
# screens: 6
# breathing: 6
# reset: 6
# day: 6
# bed: 6
# baseline: 5
# days: 5
# twice: 5
# micro: 5
# laptop: 5
# physiological: 5
# sighs: 5
# exhale: 5
# lunch: 5
# page: 5
# brain: 5
# dump: 5
# box: 5
# grounding: 5
# label: 5
# feel: 5
# cold: 5
# face: 5
# wrists: 5
# environment: 5
# modes: 5
# calendar: 5
# batch: 5
# weekly: 5
# review: 5
# shrink: 5
# sentence: 5
# add: 5
# anchors: 5
# fixed: 5
# cool: 5
# room: 5
# boundaries: 5
# hrs: 5
# persistent: 5
# insomnia: 5
# panic: 5
# mood: 5
# professional: 5
# tailor: 5
# provide: 5
# cues: 5
# social: 5
# log: 5
#
# Average of duplicated words (≥5 reps): 3.60
#
# ================================= Topic: Etymologist =================================
# pizza: 35
# th: 29
# italian: 24
# bite: 18
# latin: 16
# flatbread: 16
# southern: 15
# baked: 15
# pitta: 15
# germanic: 15
# greek: 14
# medieval: 12
# english: 12
# pizzo: 11
# meaning: 11
# term: 11
# tomato: 11
# piza: 10
# flat: 10
# pressed: 10
# early: 10
# naples: 10
# pinsa: 9
# topped: 9
# form: 9
# italy: 8
# semantic: 8
# pinsere: 7
# modern: 7
# post: 7
# rounds: 6
# lombardic: 6
# piece: 6
# morsel: 6
# sense: 6
# bread: 6
# etymology: 5
# earliest: 5
# ce: 5
# charter: 5
# gaeta: 5
# tithe: 5
# pissa: 5
# central: 5
# pound: 5
# press: 5
# vulgar: 5
# byzantine: 5
# pita: 5
# borrowed: 5
# bizzo: 5
# proto: 5
# bitana: 5
# round: 5
# toppings: 5
# narrows: 5
# yeasted: 5
# columbian: 5
# becomes: 5
# later: 5
# word: 5
# wwii: 5
# singular: 5
# plural: 5
# pizze: 5
# pizzeria: 5
# summary: 5
# likely: 5
# century: 5
#
# Average of duplicated words (≥5 reps): 3.41
#
# ================================= Topic: Commentariat =================================
# heat: 38
# clean: 24
# climate: 15
# power: 15
# carbon: 15
# management: 13
# energy: 12
# methane: 12
# flood: 11
# plans: 11
# risk: 10
# grid: 10
# electrify: 10
# pumps: 10
# change: 9
# wildfire: 9
# smoke: 9
# insurance: 9
# industrial: 9
# efficiency: 9
# infrastructure: 8
# cost: 8
# low: 8
# high: 8
# action: 8
# equity: 7
# set: 7
# permitting: 7
# end: 7
# evs: 7
# induction: 7
# insulation: 7
# public: 7
# reform: 7
# green: 7
# electricity: 7
# cut: 7
# term: 6
# temperature: 6
# gas: 6
# building: 6
# choose: 6
# standards: 6
# access: 6
# early: 6
# measure: 6
# resilience: 6
# health: 6
# exposure: 6
# clear: 5
# scalable: 5
# matters: 5
# impact: 5
# losses: 5
# supply: 5
# chain: 5
# costs: 5
# works: 5
# near: 5
# solar: 5
# wind: 5
# storage: 5
# demand: 5
# uses: 5
# medium: 5
# oil: 5
# capture: 5
# landfill: 5
# fast: 5
# controls: 5
# efficient: 5
# based: 5
# mrv: 5
# policy: 5
# pricing: 5
# durable: 5
# grids: 5
# land: 5
# use: 5
# procurement: 5
# transition: 5
# reskilling: 5
# reduce: 5
# adaptation: 5
# cooling: 5
# urban: 5
# updated: 5
# maps: 5
# zoning: 5
# resilient: 5
# scope: 5
# targets: 5
# ppas: 5
# tariffs: 5
# supplier: 5
# engagement: 5
# optimization: 5
# replace: 5
# food: 5
# waste: 5
# build: 5
# manage: 5
# residual: 5
# execution: 5
# natural: 5
#
# Average of duplicated words (≥5 reps): 3.09
#
# ================================= Topic: Magician =================================
# watch: 38
# vanish: 22
# silk: 14
# reveal: 13
# time: 13
# cloth: 13
# envelope: 11
# audience: 9
# wrap: 9
# empty: 9
# use: 8
# impossible: 8
# safe: 7
# show: 7
# isolate: 7
# misdirection: 7
# set: 7
# consent: 6
# prop: 6
# hank: 6
# box: 6
# teach: 5
# steals: 5
# based: 5
# inexpensive: 5
# devils: 5
# change: 5
# bag: 5
# handling: 5
# sealed: 5
# flies: 5
# tips: 5
# exposed: 5
# location: 5
# still: 5
# display: 5
# venue: 5
# size: 5
# runtime: 5
# secret: 5
#
# Average of duplicated words (≥5 reps): 2.89
#
# ================================= Topic: Career Counselor =================================
# cloud: 26
# security: 26
# data: 24
# weeks: 24
# basics: 19
# track: 18
# devops: 17
# tests: 17
# backend: 16
# stack: 16
# design: 16
# week: 16
# ci: 15
# frontend: 14
# language: 14
# github: 14
# full: 13
# azure: 13
# caching: 13
# auth: 13
# system: 12
# issues: 12
# roles: 11
# cd: 11
# ml: 11
# sql: 11
# eng: 11
# python: 10
# sre: 10
# aws: 10
# git: 10
# deploy: 10
# api: 10
# projects: 10
# react: 9
# typescript: 9
# testing: 9
# unit: 9
# integration: 9
# actions: 9
# rest: 9
# metrics: 9
# app: 9
# search: 9
# repos: 9
# engineering: 8
# strong: 8
# internships: 8
# demo: 8
# pagination: 8
# optional: 8
# target: 8
# current: 8
# skills: 8
# time: 8
# plan: 8
# observability: 8
# java: 7
# docker: 7
# one: 7
# month: 7
# small: 7
# jd: 7
# weekly: 7
# tailor: 7
# project: 7
# test: 7
# secure: 7
# concise: 6
# apis: 6
# infra: 6
# platform: 6
# tooling: 6
# entry: 6
# http: 6
# crud: 6
# pipeline: 6
# service: 6
# load: 6
# oss: 6
# prs: 6
# job: 6
# interviews: 6
# geography: 6
# collaboration: 5
# market: 5
# gcp: 5
# ai: 5
# fintech: 5
# healthtech: 5
# hybrid: 5
# apprenticeships: 5
# core: 5
# cs: 5
# structures: 5
# algorithms: 5
# managed: 5
# queues: 5
# cli: 5
# add: 5
# dockerize: 5
# render: 5
# fly: 5
# io: 5
# vercel: 5
# indexes: 5
# capstone: 5
# polish: 5
# portfolio: 5
# readme: 5
# rate: 5
# qualifications: 5
# degree: 5
# certs: 5
# saa: 5
# az: 5
# prep: 5
# resume: 5
# clear: 5
# readmes: 5
# networking: 5
# meetups: 5
# targeted: 5
# referrals: 5
# easy: 5
# medium: 5
# behavioral: 5
# star: 5
# resources: 5
# specs: 5
# interests: 5
# linux: 5
# starter: 5
# jobs: 5
# modeling: 5
#
# Average of duplicated words (≥5 reps): 3.95
#
# ================================= Topic: Pet Behaviorist =================================
# distance: 25
# leash: 21
# muzzle: 21
# triggers: 17
# week: 17
# body: 16
# trigger: 16
# avoid: 15
# training: 13
# short: 12
# greetings: 12
# treat: 11
# early: 11
# calm: 11
# dog: 11
# daily: 11
# conditioning: 10
# recovery: 10
# management: 9
# turn: 9
# reinforce: 9
# food: 9
# bite: 9
# plan: 8
# log: 8
# duration: 8
# time: 8
# threshold: 8
# mat: 8
# walks: 8
# history: 8
# veterinary: 8
# behavior: 8
# intensity: 8
# safety: 7
# check: 7
# name: 7
# target: 7
# cue: 7
# loose: 7
# games: 7
# quiet: 7
# parallel: 7
# escalation: 7
# certified: 7
# professional: 7
# mouth: 6
# rapid: 6
# hand: 6
# scatter: 6
# feed: 6
# walk: 6
# home: 6
# gate: 6
# end: 6
# punishment: 6
# relaxed: 6
# look: 6
# signals: 6
# pain: 5
# orthopedic: 5
# thyroid: 5
# gates: 5
# basket: 5
# positive: 5
# front: 5
# clip: 5
# harness: 5
# assess: 5
# hard: 5
# stare: 5
# settle: 5
# safe: 5
# high: 5
# value: 5
# stays: 5
# pattern: 5
# find: 5
# protocol: 5
# visitors: 5
# pre: 5
# behind: 5
# crate: 5
# stuffed: 5
# kong: 5
# use: 5
# one: 5
# movement: 5
# success: 5
# enrichment: 5
# routine: 5
# puzzles: 5
# reps: 5
# predictable: 5
# arousal: 5
# adequate: 5
# flooding: 5
# uncontrolled: 5
# parks: 5
# consult: 5
# behaviorist: 5
# dacvb: 5
# response: 5
# age: 5
# visitor: 5
#
# Average of duplicated words (≥5 reps): 3.52
#
# ================================= Topic: Personal Trainer =================================
# min: 67
# week: 31
# strength: 25
# squat: 22
# zone: 20
# row: 20
# walk: 20
# day: 19
# cardio: 17
# kg: 15
# mobility: 15
# press: 15
# weeks: 14
# intervals: 14
# push: 14
# carry: 14
# reps: 13
# add: 13
# weight: 13
# weekly: 12
# body: 12
# hinge: 12
# pull: 12
# sleep: 11
# days: 10
# kcal: 10
# protein: 10
# full: 9
# steps: 9
# baseline: 9
# easy: 9
# sets: 9
# hip: 9
# bodyweight: 9
# time: 8
# rest: 8
# leg: 8
# every: 8
# rdl: 7
# single: 7
# deload: 7
# lifts: 7
# pain: 7
# provide: 7
# plan: 6
# current: 6
# loss: 6
# training: 6
# sessions: 6
# session: 6
# split: 6
# core: 6
# progression: 6
# load: 6
# loaded: 6
# age: 5
# injuries: 5
# equipment: 5
# tailor: 5
# goal: 5
# fat: 5
# lb: 5
# per: 5
# structure: 5
# neat: 5
# rpe: 5
# pattern: 5
# goblet: 5
# back: 5
# db: 5
# overhead: 5
# pulldown: 5
# lunge: 5
# top: 5
# range: 5
# volume: 5
# conversational: 5
# bike: 5
# hard: 5
# mon: 5
# tue: 5
# wed: 5
# thu: 5
# fri: 5
# carries: 5
# sat: 5
# longer: 5
# sun: 5
# nutrition: 5
# calorie: 5
# deficit: 5
# fiber: 5
# plate: 5
# lean: 5
# carbs: 5
# healthy: 5
# fats: 5
# ml: 5
# waist: 5
# total: 5
# glute: 5
# bridge: 5
# variations: 5
# band: 5
# inverted: 5
# backpack: 5
# stop: 5
# sharp: 5
# dizziness: 5
# medical: 5
# clearance: 5
# conditions: 5
# tailored: 5
# interval: 5
# incline: 5
# thrust: 5
# light: 5
#
# Average of duplicated words (≥5 reps): 4.70
