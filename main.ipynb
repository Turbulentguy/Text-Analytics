# %% [markdown]
# ### Import libraries

# %%
from datasets import load_dataset
import pandas as pd
import numpy as np
import re
from nltk.tokenize import word_tokenize

# %% [markdown]
# ### Download dataset and transform into dataframe

# %%
df = load_dataset("fka/awesome-chatgpt-prompts")

# %%
df = pd.DataFrame(df["train"])

df.head()
# Out:
#                                act  \
# 0            An Ethereum Developer
# 1                       SEO Prompt
# 2                   Linux Terminal
# 3  English Translator and Improver
# 4           `position` Interviewer
#
#                                               prompt
# 0  Imagine you are an experienced Ethereum develo...
# 1  Using WebPilot, create an outline for an artic...
# 2  I want you to act as a linux terminal. I will ...
# 3  I want you to act as an English translator, sp...
# 4  I want you to act as an interviewer. I will be...

# %% [markdown]
# ### Check dataframe information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   act     203 non-null    object
#  1   prompt  203 non-null    object
# dtypes: object(2)
# memory usage: 3.3+ KB

# %% [markdown]
# ### Data Cleaning

# %%
def clean_text(text):
    # Convert to lowercase
    if isinstance(text, str):
        text = text.lower()
        return text
    return text

def clean_punctuation(text):
    # Remove punctuation characters
    if isinstance(text, str):
        text = re.sub(r'[^\s\w]', '', text)
        text = re.sub(r'`', '', text)
        return text
    return text

df['act'] = df['act'].apply(clean_text).apply(clean_punctuation)
df['prompt'] = df['prompt'].apply(clean_text).apply(clean_punctuation)

# %% [markdown]
# ### Data Preprocessing

# %%
df['act'] = df['act'].apply(word_tokenize)
df['prompt'] = df['prompt'].apply(word_tokenize)

# %%
df.head()
# Out:
#                                     act  \
# 0             [an, ethereum, developer]
# 1                         [seo, prompt]
# 2                     [linux, terminal]
# 3  [english, translator, and, improver]
# 4               [position, interviewer]
#
#                                               prompt
# 0  [imagine, you, are, an, experienced, ethereum,...
# 1  [using, webpilot, create, an, outline, for, an...
# 2  [i, want, you, to, act, as, a, linux, terminal...
# 3  [i, want, you, to, act, as, an, english, trans...
# 4  [i, want, you, to, act, as, an, interviewer, i...
